# %% [markdown]
# <a href="https://colab.research.google.com/github/VasyaKhokhlov/web-technologies/blob/main/%D0%9A%D0%BE%D0%B4%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D0%BA%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  human
# 3  robot
# 4  robot

# %%
import pandas as pd
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head(10)
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  robot
# 4  robot
# 5  robot
# 6  human
# 7  robot
# 8  robot
# 9  robot

# %%
pd.get_dummies(data['whoAmI']).head(10)
# Out:
#    human  robot
# 0      1      0
# 1      1      0
# 2      0      1
# 3      0      1
# 4      0      1
# 5      0      1
# 6      1      0
# 7      0      1
# 8      0      1
# 9      0      1

# %%
pd.DataFrame({'human': data['whoAmI'] == 'human',
              'robot': data['whoAmI'] == 'robot'}).astype(int).head(10)
# Out:
#    human  robot
# 0      1      0
# 1      1      0
# 2      0      1
# 3      0      1
# 4      0      1
# 5      0      1
# 6      1      0
# 7      0      1
# 8      0      1
# 9      0      1
